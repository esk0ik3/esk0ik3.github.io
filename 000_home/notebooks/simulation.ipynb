# %% [markdown]
# # 三角関数のグラフ

# %%
import numpy as np
import matplotlib.pyplot as plt

# データの生成
x = np.linspace(0, 2 * np.pi, 100)
y_sin = np.sin(x)
y_cos = np.cos(x)

# グラフの描画
plt.figure(figsize=(8, 5))
plt.plot(x, y_sin, label='$\sin(x)$', color='blue')
plt.plot(x, y_cos, label='$\cos(x)$', color='red', linestyle='--')

# グラフの装飾
plt.title('Sine and Cosine Waves')
plt.xlabel('Phase [rad]')
plt.ylabel('Amplitude')
plt.grid(True, which='both', linestyle='--', alpha=0.5)
plt.axhline(y=0, color='k', linewidth=1)
plt.legend()

plt.show()
# Out:
# <>:11: SyntaxWarning: invalid escape sequence '\s'
# <>:12: SyntaxWarning: invalid escape sequence '\c'
# <>:11: SyntaxWarning: invalid escape sequence '\s'
# <>:12: SyntaxWarning: invalid escape sequence '\c'
# /tmp/ipykernel_29482/1535640995.py:11: SyntaxWarning: invalid escape sequence '\s'
#   plt.plot(x, y_sin, label='$\sin(x)$', color='blue')
# /tmp/ipykernel_29482/1535640995.py:12: SyntaxWarning: invalid escape sequence '\c'
#   plt.plot(x, y_cos, label='$\cos(x)$', color='red', linestyle='--')
